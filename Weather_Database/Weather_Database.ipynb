# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Import the requests library.

import requests

# Import the API key.

from config import weather_api_key

# Import the time library and the datetime module from the datetime library 

import time
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Assign Coordinates
coordinates = list(lat_lngs)

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | ahipara
# Processing Record 3 of Set 1 | cancun
# Processing Record 4 of Set 1 | egvekinot
# Processing Record 5 of Set 1 | nizhniy tsasuchey
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | owando
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | dwarka
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | tari
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | thessalon
# Processing Record 17 of Set 1 | komsomolskiy
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | gondar
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | vyshkov
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | faya
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | karratha
# Processing Record 28 of Set 1 | college
# Processing Record 29 of Set 1 | meulaboh
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | sovetskiy
# Processing Record 32 of Set 1 | dingle
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | baykit
# Processing Record 36 of Set 1 | grindavik
# Processing Record 37 of Set 1 | hobyo
# Processing Record 38 of Set 1 | filingue
# Processing Record 39 of Set 1 | kaeo
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | mogadishu
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | aswan
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | grand-santi
# Processing Record 46 of Set 1 | bonthe
# Processing Record 47 of Set 1 | lata
# Processing Record 48 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | hare bay
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | norman wells
# Processing Record 3 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 2 | lagoa
# Processing Record 5 of Set 2 | henties bay
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | rabo de peixe
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | codrington
# Processing Record 16 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 2 | esperance
# Processing Record 18 of Set 2 | yulara
# Processing Record 19 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 2 | cayenne
# Processing Record 21 of Set 2 | comodoro rivadavia
# Processing Record 22 of Set 2 | paita
# Processing Record 23 of Set 2 | ngunguru
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | kamenka
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | parlakimidi
# Processing Record 30 of Set 2 | ilhabela
# Processing Record 31 of Set 2 | kloulklubed
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | hanstholm
# Processing Record 34 of Set 2 | husavik
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | kibala
# Processing Record 37 of Set 2 | lompoc
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | avera
# Processing Record 40 of Set 2 | san jose
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | bubaque
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | burica
# City not found. Skipping...
# Processing Record 46 of Set 2 | santa cruz
# Processing Record 47 of Set 2 | aras
# Processing Record 48 of Set 2 | olavarria
# Processing Record 49 of Set 2 | beruwala
# Processing Record 50 of Set 2 | kimbe
# Processing Record 1 of Set 3 | zhigansk
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | adrar
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | oktyabrskiy
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | allapalli
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | korla
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 13 of Set 3 | micheldorf
# Processing Record 14 of Set 3 | kushiro
# Processing Record 15 of Set 3 | wembley
# Processing Record 16 of Set 3 | airai
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | axim
# Processing Record 19 of Set 3 | talnakh
# Processing Record 20 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 3 | ucluelet
# Processing Record 22 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 3 | cockburn town
# Processing Record 24 of Set 3 | deputatskiy
# Processing Record 25 of Set 3 | punta arenas
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | dovolnoye
# Processing Record 29 of Set 3 | jega
# Processing Record 30 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 3 | khatanga
# Processing Record 32 of Set 3 | saint-augustin
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 3 | la baule-escoublac
# Processing Record 37 of Set 3 | ilulissat
# Processing Record 38 of Set 3 | kavaratti
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | gazimurskiy zavod
# Processing Record 41 of Set 3 | makakilo city
# Processing Record 42 of Set 3 | faanui
# Processing Record 43 of Set 3 | leningradskiy
# Processing Record 44 of Set 3 | geraldton
# Processing Record 45 of Set 3 | ereymentau
# Processing Record 46 of Set 3 | boyolangu
# Processing Record 47 of Set 3 | fairbanks
# Processing Record 48 of Set 3 | monrovia
# Processing Record 49 of Set 3 | winnemucca
# Processing Record 50 of Set 3 | makushino
# Processing Record 1 of Set 4 | beitbridge
# Processing Record 2 of Set 4 | kadiri
# Processing Record 3 of Set 4 | venice
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 4 | lobatse
# Processing Record 6 of Set 4 | lithakia
# Processing Record 7 of Set 4 | careiro da varzea
# Processing Record 8 of Set 4 | provideniya
# Processing Record 9 of Set 4 | san carlos del zulia
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | nanortalik
# Processing Record 12 of Set 4 | isiro
# Processing Record 13 of Set 4 | mount gambier
# Processing Record 14 of Set 4 | songkhla
# Processing Record 15 of Set 4 | trat
# Processing Record 16 of Set 4 | sitka
# Processing Record 17 of Set 4 | derzhavinsk
# Processing Record 18 of Set 4 | daru
# Processing Record 19 of Set 4 | saint anthony
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | moratuwa
# Processing Record 22 of Set 4 | antalaha
# Processing Record 23 of Set 4 | ryotsu
# Processing Record 24 of Set 4 | kapaa
# Processing Record 25 of Set 4 | qaqortoq
# Processing Record 26 of Set 4 | tiquisate
# Processing Record 27 of Set 4 | sindand
# City not found. Skipping...
# Processing Record 28 of Set 4 | shache
# Processing Record 29 of Set 4 | masty
# Processing Record 30 of Set 4 | seydi
# Processing Record 31 of Set 4 | valparaiso
# Processing Record 32 of Set 4 | ponta delgada
# Processing Record 33 of Set 4 | pestravka
# Processing Record 34 of Set 4 | flin flon
# Processing Record 35 of Set 4 | novikovo
# Processing Record 36 of Set 4 | san luis
# Processing Record 37 of Set 4 | nhulunbuy
# Processing Record 38 of Set 4 | kenai
# Processing Record 39 of Set 4 | la ronge
# Processing Record 40 of Set 4 | lavrentiya
# Processing Record 41 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 4 | salamanca
# Processing Record 43 of Set 4 | itoman
# Processing Record 44 of Set 4 | bintulu
# Processing Record 45 of Set 4 | georgetown
# Processing Record 46 of Set 4 | vila velha
# Processing Record 47 of Set 4 | rome
# Processing Record 48 of Set 4 | neiafu
# Processing Record 49 of Set 4 | polis
# Processing Record 50 of Set 4 | hammerfest
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | waiouru
# Processing Record 3 of Set 5 | ormara
# Processing Record 4 of Set 5 | mehamn
# Processing Record 5 of Set 5 | sinjar
# Processing Record 6 of Set 5 | rodney
# Processing Record 7 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 5 | hami
# Processing Record 9 of Set 5 | port macquarie
# Processing Record 10 of Set 5 | amapa
# Processing Record 11 of Set 5 | tsiroanomandidy
# Processing Record 12 of Set 5 | ende
# Processing Record 13 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 5 | puerto ayacucho
# Processing Record 15 of Set 5 | poya
# Processing Record 16 of Set 5 | ixtapa
# Processing Record 17 of Set 5 | waingapu
# Processing Record 18 of Set 5 | aloleng
# Processing Record 19 of Set 5 | wairoa
# Processing Record 20 of Set 5 | castro
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | wittstock
# Processing Record 23 of Set 5 | cap-chat
# Processing Record 24 of Set 5 | mangrol
# Processing Record 25 of Set 5 | vodnyy
# Processing Record 26 of Set 5 | hilo
# Processing Record 27 of Set 5 | puerto carreno
# Processing Record 28 of Set 5 | tadine
# Processing Record 29 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 5 | shediac
# Processing Record 31 of Set 5 | palana
# Processing Record 32 of Set 5 | half moon bay
# Processing Record 33 of Set 5 | fortuna
# Processing Record 34 of Set 5 | aripuana
# Processing Record 35 of Set 5 | baherden
# Processing Record 36 of Set 5 | moron
# Processing Record 37 of Set 5 | seymchan
# Processing Record 38 of Set 5 | fuling
# Processing Record 39 of Set 5 | mujiayingzi
# Processing Record 40 of Set 5 | fallon
# Processing Record 41 of Set 5 | huarmey
# Processing Record 42 of Set 5 | touros
# Processing Record 43 of Set 5 | chuy
# Processing Record 44 of Set 5 | soyo
# Processing Record 45 of Set 5 | canutama
# Processing Record 46 of Set 5 | dakar
# Processing Record 47 of Set 5 | mackay
# Processing Record 48 of Set 5 | hohhot
# Processing Record 49 of Set 5 | santa maria del oro
# Processing Record 50 of Set 5 | tyukalinsk
# Processing Record 1 of Set 6 | poum
# Processing Record 2 of Set 6 | lincoln
# Processing Record 3 of Set 6 | lisakovsk
# Processing Record 4 of Set 6 | upernavik
# Processing Record 5 of Set 6 | salinopolis
# Processing Record 6 of Set 6 | cabo san lucas
# Processing Record 7 of Set 6 | khirkiya
# Processing Record 8 of Set 6 | damghan
# Processing Record 9 of Set 6 | anadyr
# Processing Record 10 of Set 6 | oyon
# Processing Record 11 of Set 6 | gallup
# Processing Record 12 of Set 6 | mobaye
# Processing Record 13 of Set 6 | ulety
# Processing Record 14 of Set 6 | kavieng
# Processing Record 15 of Set 6 | jumla
# Processing Record 16 of Set 6 | saint george
# Processing Record 17 of Set 6 | pisco
# Processing Record 18 of Set 6 | yarmouth
# Processing Record 19 of Set 6 | dunmore east
# Processing Record 20 of Set 6 | timra
# Processing Record 21 of Set 6 | mpika
# Processing Record 22 of Set 6 | portland
# Processing Record 23 of Set 6 | fredericksburg
# Processing Record 24 of Set 6 | arlit
# Processing Record 25 of Set 6 | nome
# Processing Record 26 of Set 6 | mauldin
# Processing Record 27 of Set 6 | yakeshi
# Processing Record 28 of Set 6 | pedreiras
# Processing Record 29 of Set 6 | chokurdakh
# Processing Record 30 of Set 6 | fort nelson
# Processing Record 31 of Set 6 | karasjok
# Processing Record 32 of Set 6 | hovd
# Processing Record 33 of Set 6 | ketchikan
# Processing Record 34 of Set 6 | harper
# Processing Record 35 of Set 6 | satkhira
# Processing Record 36 of Set 6 | itarema
# Processing Record 37 of Set 6 | brae
# Processing Record 38 of Set 6 | poronaysk
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | tura
# Processing Record 41 of Set 6 | new norfolk
# Processing Record 42 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 6 | tiznit
# Processing Record 44 of Set 6 | maningrida
# Processing Record 45 of Set 6 | tirumullaivasal
# Processing Record 46 of Set 6 | ouallam
# Processing Record 47 of Set 6 | karaton
# Processing Record 48 of Set 6 | vestmanna
# Processing Record 49 of Set 6 | hit
# Processing Record 50 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 7 | mandalgovi
# Processing Record 2 of Set 7 | krasnoborsk
# Processing Record 3 of Set 7 | apatou
# Processing Record 4 of Set 7 | jubb jannin
# City not found. Skipping...
# Processing Record 5 of Set 7 | thinadhoo
# Processing Record 6 of Set 7 | hamilton
# Processing Record 7 of Set 7 | leh
# Processing Record 8 of Set 7 | sioux lookout
# Processing Record 9 of Set 7 | bathsheba
# Processing Record 10 of Set 7 | saskylakh
# Processing Record 11 of Set 7 | inongo
# Processing Record 12 of Set 7 | okhotsk
# Processing Record 13 of Set 7 | vestmannaeyjar
# Processing Record 14 of Set 7 | phanat nikhom
# Processing Record 15 of Set 7 | shenjiamen
# Processing Record 16 of Set 7 | broome
# Processing Record 17 of Set 7 | tual
# Processing Record 18 of Set 7 | saint-pierre
# Processing Record 19 of Set 7 | evensk
# Processing Record 20 of Set 7 | srem
# Processing Record 21 of Set 7 | zhenjiang
# Processing Record 22 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 7 | biak
# Processing Record 24 of Set 7 | kopyevo
# City not found. Skipping...
# Processing Record 25 of Set 7 | saint-joseph
# Processing Record 26 of Set 7 | wahiawa
# Processing Record 27 of Set 7 | launceston
# Processing Record 28 of Set 7 | kuching
# Processing Record 29 of Set 7 | bowen
# Processing Record 30 of Set 7 | laguna
# Processing Record 31 of Set 7 | bambous virieux
# Processing Record 32 of Set 7 | cochabamba
# Processing Record 33 of Set 7 | iskateley
# Processing Record 34 of Set 7 | krasnoselkup
# Processing Record 35 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 36 of Set 7 | lae
# Processing Record 37 of Set 7 | chapais
# Processing Record 38 of Set 7 | wewak
# Processing Record 39 of Set 7 | marrakesh
# Processing Record 40 of Set 7 | vila franca do campo
# Processing Record 41 of Set 7 | le mans
# Processing Record 42 of Set 7 | fenoarivo
# Processing Record 43 of Set 7 | clarence town
# Processing Record 44 of Set 7 | isangel
# Processing Record 45 of Set 7 | hukuntsi
# Processing Record 46 of Set 7 | chicama
# Processing Record 47 of Set 7 | kutum
# Processing Record 48 of Set 7 | bonavista
# Processing Record 49 of Set 7 | chandbali
# Processing Record 50 of Set 7 | funadhoo
# Processing Record 1 of Set 8 | rahuri
# Processing Record 2 of Set 8 | venado tuerto
# Processing Record 3 of Set 8 | senanga
# Processing Record 4 of Set 8 | pangody
# Processing Record 5 of Set 8 | katobu
# Processing Record 6 of Set 8 | hermsdorf
# Processing Record 7 of Set 8 | eureka
# Processing Record 8 of Set 8 | beyneu
# Processing Record 9 of Set 8 | iqaluit
# Processing Record 10 of Set 8 | sobolevo
# Processing Record 11 of Set 8 | torbay
# Processing Record 12 of Set 8 | yurimaguas
# Processing Record 13 of Set 8 | sibu
# Processing Record 14 of Set 8 | marsh harbour
# Processing Record 15 of Set 8 | baruun-urt
# Processing Record 16 of Set 8 | honningsvag
# Processing Record 17 of Set 8 | jasper
# Processing Record 18 of Set 8 | lagos
# Processing Record 19 of Set 8 | igbo ora
# Processing Record 20 of Set 8 | harbour breton
# Processing Record 21 of Set 8 | ilava
# Processing Record 22 of Set 8 | pangnirtung
# Processing Record 23 of Set 8 | hasaki
# Processing Record 24 of Set 8 | huilong
# Processing Record 25 of Set 8 | ladovskaya balka
# Processing Record 26 of Set 8 | oussouye
# Processing Record 27 of Set 8 | baghdad
# Processing Record 28 of Set 8 | rorvik
# Processing Record 29 of Set 8 | naze
# Processing Record 30 of Set 8 | miri
# Processing Record 31 of Set 8 | eslov
# Processing Record 32 of Set 8 | shingu
# Processing Record 33 of Set 8 | aksarka
# Processing Record 34 of Set 8 | santa maria
# Processing Record 35 of Set 8 | charters towers
# Processing Record 36 of Set 8 | olafsvik
# Processing Record 37 of Set 8 | sisimiut
# Processing Record 38 of Set 8 | ust-donetskiy
# Processing Record 39 of Set 8 | hofn
# Processing Record 40 of Set 8 | palu
# Processing Record 41 of Set 8 | bantou
# Processing Record 42 of Set 8 | huanren
# Processing Record 43 of Set 8 | mgandu
# Processing Record 44 of Set 8 | anchorage
# Processing Record 45 of Set 8 | calatayud
# Processing Record 46 of Set 8 | blind river
# Processing Record 47 of Set 8 | ostrovnoy
# Processing Record 48 of Set 8 | lamar
# Processing Record 49 of Set 8 | bani
# Processing Record 50 of Set 8 | wanning
# Processing Record 1 of Set 9 | luangwa
# Processing Record 2 of Set 9 | champerico
# Processing Record 3 of Set 9 | puerto escondido
# Processing Record 4 of Set 9 | samarai
# Processing Record 5 of Set 9 | saint charles
# Processing Record 6 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | phangnga
# Processing Record 8 of Set 9 | port hardy
# Processing Record 9 of Set 9 | pacific grove
# Processing Record 10 of Set 9 | labuhan
# Processing Record 11 of Set 9 | alugan
# Processing Record 12 of Set 9 | bouza
# Processing Record 13 of Set 9 | san andres
# Processing Record 14 of Set 9 | saquarema
# Processing Record 15 of Set 9 | griffith
# Processing Record 16 of Set 9 | nurota
# Processing Record 17 of Set 9 | susangerd
# Processing Record 18 of Set 9 | dicabisagan
# Processing Record 19 of Set 9 | kapiri mposhi
# Processing Record 20 of Set 9 | wharton
# Processing Record 21 of Set 9 | nantucket
# Processing Record 22 of Set 9 | smolensk
# Processing Record 23 of Set 9 | nanton
# Processing Record 24 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 9 | lasa
# Processing Record 26 of Set 9 | gap
# Processing Record 27 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 9 | guerrero negro
# Processing Record 29 of Set 9 | igarka
# Processing Record 30 of Set 9 | vostok
# Processing Record 31 of Set 9 | clyde river
# Processing Record 32 of Set 9 | lorengau
# Processing Record 33 of Set 9 | hambantota
# Processing Record 34 of Set 9 | nuoro
# Processing Record 35 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 9 | muros
# Processing Record 37 of Set 9 | saint-francois
# Processing Record 38 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 39 of Set 9 | jacareacanga
# Processing Record 40 of Set 9 | motygino
# Processing Record 41 of Set 9 | hay river
# Processing Record 42 of Set 9 | cidreira
# Processing Record 43 of Set 9 | rantepao
# Processing Record 44 of Set 9 | fuxin
# Processing Record 45 of Set 9 | visby
# Processing Record 46 of Set 9 | chara
# Processing Record 47 of Set 9 | lagunas
# Processing Record 48 of Set 9 | crotone
# Processing Record 49 of Set 9 | kanakapura
# Processing Record 50 of Set 9 | namatanai
# Processing Record 1 of Set 10 | paamiut
# Processing Record 2 of Set 10 | verkhnevilyuysk
# Processing Record 3 of Set 10 | devin
# Processing Record 4 of Set 10 | sarkand
# Processing Record 5 of Set 10 | tynda
# Processing Record 6 of Set 10 | arivonimamo
# Processing Record 7 of Set 10 | benguela
# Processing Record 8 of Set 10 | camacha
# Processing Record 9 of Set 10 | new waterford
# Processing Record 10 of Set 10 | pitimbu
# Processing Record 11 of Set 10 | pontian kecil
# Processing Record 12 of Set 10 | san miguel el alto
# Processing Record 13 of Set 10 | kang
# Processing Record 14 of Set 10 | rocha
# Processing Record 15 of Set 10 | coahuayana
# Processing Record 16 of Set 10 | havre-saint-pierre
# Processing Record 17 of Set 10 | waterloo
# Processing Record 18 of Set 10 | shawnee
# Processing Record 19 of Set 10 | northam
# Processing Record 20 of Set 10 | jalu
# Processing Record 21 of Set 10 | koutsouras
# Processing Record 22 of Set 10 | mandera
# Processing Record 23 of Set 10 | shelburne
# Processing Record 24 of Set 10 | dekar
# Processing Record 25 of Set 10 | tokmak
# Processing Record 26 of Set 10 | narsaq
# Processing Record 27 of Set 10 | ribeira brava
# Processing Record 28 of Set 10 | sola
# Processing Record 29 of Set 10 | zarautz
# Processing Record 30 of Set 10 | khelyulya
# Processing Record 31 of Set 10 | adana
# Processing Record 32 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 10 | gravelbourg
# Processing Record 34 of Set 10 | whitecourt
# Processing Record 35 of Set 10 | tselinnoye
# Processing Record 36 of Set 10 | acaponeta
# Processing Record 37 of Set 10 | plettenberg bay
# Processing Record 38 of Set 10 | mitchell
# Processing Record 39 of Set 10 | sabha
# Processing Record 40 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 10 | north bay
# Processing Record 42 of Set 10 | bolshevik
# Processing Record 43 of Set 10 | constitucion
# Processing Record 44 of Set 10 | peniche
# Processing Record 45 of Set 10 | caibarien
# Processing Record 46 of Set 10 | vanino
# Processing Record 47 of Set 10 | sur
# Processing Record 48 of Set 10 | ust-shonosha
# Processing Record 49 of Set 10 | dargaville
# Processing Record 50 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 11 | zubtsov
# Processing Record 3 of Set 11 | hadimkoy
# City not found. Skipping...
# Processing Record 4 of Set 11 | campbell river
# Processing Record 5 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 11 | umm bab
# Processing Record 7 of Set 11 | westport
# Processing Record 8 of Set 11 | karpogory
# Processing Record 9 of Set 11 | bairiki
# Processing Record 10 of Set 11 | lewistown
# Processing Record 11 of Set 11 | camana
# Processing Record 12 of Set 11 | gizo
# Processing Record 13 of Set 11 | klaksvik
# Processing Record 14 of Set 11 | nakama
# Processing Record 15 of Set 11 | katsuura
# Processing Record 16 of Set 11 | kongolo
# Processing Record 17 of Set 11 | nilopolis
# Processing Record 18 of Set 11 | portel
# Processing Record 19 of Set 11 | asyut
# Processing Record 20 of Set 11 | twentynine palms
# Processing Record 21 of Set 11 | bandarbeyla
# Processing Record 22 of Set 11 | vallenar
# Processing Record 23 of Set 11 | salalah
# Processing Record 24 of Set 11 | san patricio
# Processing Record 25 of Set 11 | vao
# Processing Record 26 of Set 11 | luderitz
# Processing Record 27 of Set 11 | pangai
# Processing Record 28 of Set 11 | makarov
# Processing Record 29 of Set 11 | bom jesus da lapa
# Processing Record 30 of Set 11 | uberlandia
# Processing Record 31 of Set 11 | novobirilyussy
# Processing Record 32 of Set 11 | vilhena
# Processing Record 33 of Set 11 | duobao
# Processing Record 34 of Set 11 | bichura
# Processing Record 35 of Set 11 | padang
# Processing Record 36 of Set 11 | mbala
# Processing Record 37 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 11 | masallatah
# Processing Record 39 of Set 11 | magdagachi
# Processing Record 40 of Set 11 | asau
# Processing Record 41 of Set 11 | batagay-alyta
# Processing Record 42 of Set 11 | nushki
# Processing Record 43 of Set 11 | mabaruma
# Processing Record 44 of Set 11 | greencastle
# Processing Record 45 of Set 11 | north bend
# Processing Record 46 of Set 11 | suffolk
# Processing Record 47 of Set 11 | caravelas
# Processing Record 48 of Set 11 | rochester
# Processing Record 49 of Set 11 | lucapa
# Processing Record 50 of Set 11 | sao gabriel da cachoeira
# Processing Record 1 of Set 12 | piney green
# Processing Record 2 of Set 12 | manjeshwar
# Processing Record 3 of Set 12 | dom pedrito
# Processing Record 4 of Set 12 | waddan
# Processing Record 5 of Set 12 | umm lajj
# Processing Record 6 of Set 12 | maryville
# Processing Record 7 of Set 12 | shuangcheng
# Processing Record 8 of Set 12 | numan
# Processing Record 9 of Set 12 | birin
# Processing Record 10 of Set 12 | alofi
# Processing Record 11 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 12 | zhanakorgan
# Processing Record 14 of Set 12 | voi
# Processing Record 15 of Set 12 | safranbolu
# Processing Record 16 of Set 12 | weligama
# Processing Record 17 of Set 12 | erzurum
# Processing Record 18 of Set 12 | aranos
# Processing Record 19 of Set 12 | tshikapa
# Processing Record 20 of Set 12 | deyang
# Processing Record 21 of Set 12 | yumen
# Processing Record 22 of Set 12 | port hueneme
# Processing Record 23 of Set 12 | shalya
# Processing Record 24 of Set 12 | pueblo nuevo
# Processing Record 25 of Set 12 | koroni
# Processing Record 26 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 27 of Set 12 | ulan-ude
# Processing Record 28 of Set 12 | kifri
# Processing Record 29 of Set 12 | kirakira
# Processing Record 30 of Set 12 | arinos
# Processing Record 31 of Set 12 | asfi
# Processing Record 32 of Set 12 | paracuru
# Processing Record 33 of Set 12 | san lawrenz
# Processing Record 34 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 35 of Set 12 | haines junction
# Processing Record 36 of Set 12 | rehoboth
# Processing Record 37 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 12 | nabire
# Processing Record 39 of Set 12 | katherine
# Processing Record 40 of Set 12 | yichang
# Processing Record 41 of Set 12 | taoudenni
# Processing Record 42 of Set 12 | manyana
# Processing Record 43 of Set 12 | takoradi
# Processing Record 44 of Set 12 | mount isa
# Processing Record 45 of Set 12 | ondjiva
# Processing Record 46 of Set 12 | abu dhabi
# Processing Record 47 of Set 12 | aklavik
# Processing Record 48 of Set 12 | vardo
# Processing Record 49 of Set 12 | krasnoarmeysk
# Processing Record 50 of Set 12 | le port
# Processing Record 1 of Set 13 | kingman
# Processing Record 2 of Set 13 | loa janan
# Processing Record 3 of Set 13 | troitsko-pechorsk
# Processing Record 4 of Set 13 | dalby
# Processing Record 5 of Set 13 | koungou
# Processing Record 6 of Set 13 | bonnyville
# Processing Record 7 of Set 13 | antofagasta
# Processing Record 8 of Set 13 | whitehorse
# Processing Record 9 of Set 13 | mikumi
# Processing Record 10 of Set 13 | dujuma
# City not found. Skipping...
# Processing Record 11 of Set 13 | samana
# Processing Record 12 of Set 13 | ulyanovo
# City not found. Skipping...
# Processing Record 13 of Set 13 | mangan
# Processing Record 14 of Set 13 | broken hill
# Processing Record 15 of Set 13 | nishihara
# Processing Record 16 of Set 13 | oga
# Processing Record 17 of Set 13 | kungurtug
# Processing Record 18 of Set 13 | port hedland
# Processing Record 19 of Set 13 | sundargarh
# Processing Record 20 of Set 13 | coquimbo
# Processing Record 21 of Set 13 | yendi
# Processing Record 22 of Set 13 | tuatapere
# Processing Record 23 of Set 13 | okmulgee
# Processing Record 24 of Set 13 | kizukuri
# Processing Record 25 of Set 13 | las guacamayas
# Processing Record 26 of Set 13 | tazovskiy
# Processing Record 27 of Set 13 | bereda
# Processing Record 28 of Set 13 | kieta
# Processing Record 29 of Set 13 | yomou
# Processing Record 30 of Set 13 | corinto
# Processing Record 31 of Set 13 | belaya gora
# Processing Record 32 of Set 13 | camopi
# Processing Record 33 of Set 13 | roma
# Processing Record 34 of Set 13 | storozhevaya
# Processing Record 35 of Set 13 | mazamari
# Processing Record 36 of Set 13 | jizan
# Processing Record 37 of Set 13 | sawtell
# Processing Record 38 of Set 13 | najran
# Processing Record 39 of Set 13 | turukhansk
# Processing Record 40 of Set 13 | pyaozerskiy
# Processing Record 41 of Set 13 | maceio
# Processing Record 42 of Set 13 | barcelos
# Processing Record 43 of Set 13 | minab
# Processing Record 44 of Set 13 | west wendover
# Processing Record 45 of Set 13 | sindou
# Processing Record 46 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 13 | quartucciu
# Processing Record 48 of Set 13 | stavern
# Processing Record 49 of Set 13 | miracema do tocantins
# Processing Record 50 of Set 13 | nuuk
# Processing Record 1 of Set 14 | okha
# Processing Record 2 of Set 14 | kongoussi
# Processing Record 3 of Set 14 | nelson bay
# Processing Record 4 of Set 14 | aksu
# Processing Record 5 of Set 14 | kalmunai
# Processing Record 6 of Set 14 | ejura
# Processing Record 7 of Set 14 | sheltozero
# Processing Record 8 of Set 14 | xiuyan
# Processing Record 9 of Set 14 | uray
# Processing Record 10 of Set 14 | maldonado
# Processing Record 11 of Set 14 | the valley
# Processing Record 12 of Set 14 | puerto leguizamo
# Processing Record 13 of Set 14 | isla vista
# Processing Record 14 of Set 14 | richard toll
# City not found. Skipping...
# Processing Record 15 of Set 14 | faenza
# Processing Record 16 of Set 14 | lanzhou
# Processing Record 17 of Set 14 | basco
# Processing Record 18 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 14 | kouroussa
# Processing Record 20 of Set 14 | maxixe
# Processing Record 21 of Set 14 | tabas
# Processing Record 22 of Set 14 | nichinan
# Processing Record 23 of Set 14 | pilar
# Processing Record 24 of Set 14 | sistranda
# Processing Record 25 of Set 14 | lichinga
# Processing Record 26 of Set 14 | maniitsoq
# Processing Record 27 of Set 14 | bilibino
# Processing Record 28 of Set 14 | litovko
# Processing Record 29 of Set 14 | ugoofaaru
# Processing Record 30 of Set 14 | rakiv lis
# Processing Record 31 of Set 14 | kulhudhuffushi
# Processing Record 32 of Set 14 | corn island
# Processing Record 33 of Set 14 | martapura
# Processing Record 34 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 35 of Set 14 | erechim
# Processing Record 36 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 37 of Set 14 | araouane
# Processing Record 38 of Set 14 | palaiokhora
# City not found. Skipping...
# Processing Record 39 of Set 14 | kahului
# Processing Record 40 of Set 14 | mitsamiouli
# Processing Record 41 of Set 14 | estelle
# Processing Record 42 of Set 14 | talagang
# Processing Record 43 of Set 14 | goderich
# Processing Record 44 of Set 14 | kiruna
# Processing Record 45 of Set 14 | sorland
# Processing Record 46 of Set 14 | tigil
# Processing Record 47 of Set 14 | kovur
# Processing Record 48 of Set 14 | bolonchen
# City not found. Skipping...
# Processing Record 49 of Set 14 | tautira
# Processing Record 50 of Set 14 | japura
# Processing Record 1 of Set 15 | morro bay
# Processing Record 2 of Set 15 | alausi
# Processing Record 3 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 15 | abu samrah
# Processing Record 5 of Set 15 | chon daen
# Processing Record 6 of Set 15 | alice springs
# Processing Record 7 of Set 15 | cairns
# Processing Record 8 of Set 15 | kysyl-syr
# Processing Record 9 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 10 of Set 15 | esperantina
# Processing Record 11 of Set 15 | victoria
# Processing Record 12 of Set 15 | jinchang
# Processing Record 13 of Set 15 | mahur
# Processing Record 14 of Set 15 | port blair
# Processing Record 15 of Set 15 | hirara
# Processing Record 16 of Set 15 | aitape
# Processing Record 17 of Set 15 | banjar
# Processing Record 18 of Set 15 | srednekolymsk
# Processing Record 19 of Set 15 | dali
# Processing Record 20 of Set 15 | finschhafen
# Processing Record 21 of Set 15 | sosnovo-ozerskoye
# Processing Record 22 of Set 15 | hualmay
# Processing Record 23 of Set 15 | kultuk
# Processing Record 24 of Set 15 | merauke
# Processing Record 25 of Set 15 | maragogi
# Processing Record 26 of Set 15 | khandyga
# Processing Record 27 of Set 15 | inhambane
# Processing Record 28 of Set 15 | roald
# Processing Record 29 of Set 15 | mantua
# Processing Record 30 of Set 15 | svetlogorsk
# Processing Record 31 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 15 | nemuro
# Processing Record 33 of Set 15 | raudeberg
# Processing Record 34 of Set 15 | cherskiy
# Processing Record 35 of Set 15 | catia la mar
# Processing Record 36 of Set 15 | sigiriya
# Processing Record 37 of Set 15 | kedrovyy
# Processing Record 38 of Set 15 | noshiro
# Processing Record 39 of Set 15 | kondinskoye
# Processing Record 40 of Set 15 | partenit
# Processing Record 41 of Set 15 | zyryanka
# Processing Record 42 of Set 15 | tamandare
# Processing Record 43 of Set 15 | seoul

# %%
len(city_data)
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Rikitea      PF -23.1203 -134.9692     73.20        69
# 1            Ahipara      NZ -35.1667  173.1667     55.51        58
# 2             Cancun      MX  21.1743  -86.8466     82.33        83
# 3          Egvekinot      RU  66.3167 -179.1667     51.01        80
# 4  Nizhniy Tsasuchey      RU  50.5167  115.1333     71.67        43
# 5        East London      ZA -33.0153   27.9116     63.88        42
# 6             Owando      CG  -0.4819   15.8999     73.62        62
# 7     Severo-Kurilsk      RU  50.6789  156.1250     57.07        96
# 8             Dwarka      IN  22.2394   68.9678     82.13        87
# 9             Bethel      US  41.3712  -73.4140     77.36        79
#
#    Cloudiness  Wind Speed Current Description
# 0          62       20.51       broken clouds
# 1          13       12.68          few clouds
# 2          20        4.61          few clouds
# 3         100        4.00     overcast clouds
# 4          27       13.98    scattered clouds
# 5          51        4.74       broken clouds
# 6          71        3.62       broken clouds
# 7         100       10.89     overcast clouds
# 8         100        9.08     overcast clouds
# 9          88        4.16     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Rikitea      PF -23.1203 -134.9692     73.20        69
# 1              Ahipara      NZ -35.1667  173.1667     55.51        58
# 2               Cancun      MX  21.1743  -86.8466     82.33        83
# 3            Egvekinot      RU  66.3167 -179.1667     51.01        80
# 4    Nizhniy Tsasuchey      RU  50.5167  115.1333     71.67        43
# ..                 ...     ...      ...       ...       ...       ...
# 682        Kondinskoye      RU  59.6481   67.4100     59.45        84
# 683           Partenit      UA  44.5780   34.3446     73.58        72
# 684           Zyryanka      RU  65.7500  150.8500     78.48        40
# 685          Tamandare      BR  -8.7597  -35.1047     73.35        85
# 686              Seoul      KR  37.5683  126.9778     87.19        63
#
#      Cloudiness  Wind Speed Current Description
# 0            62       20.51       broken clouds
# 1            13       12.68          few clouds
# 2            20        4.61          few clouds
# 3           100        4.00     overcast clouds
# 4            27       13.98    scattered clouds
# ..          ...         ...                 ...
# 682         100        8.77     overcast clouds
# 683           0        4.50           clear sky
# 684          30        9.44    scattered clouds
# 685           4        2.71           clear sky
# 686          20        3.44          few clouds
#
# [687 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
